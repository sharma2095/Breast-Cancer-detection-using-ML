# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\amans\Downloads\Breast_cancer_data.csv')

# %%
df.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df.describe()
# Out:
#        mean_radius  mean_texture  mean_perimeter    mean_area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean_smoothness   diagnosis
# count       569.000000  569.000000
# mean          0.096360    0.627417
# std           0.014064    0.483918
# min           0.052630    0.000000
# 25%           0.086370    0.000000
# 50%           0.095870    1.000000
# 75%           0.105300    1.000000
# max           0.163400    1.000000

# %%
df.shape
# Out:
# (569, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mean_radius      569 non-null    float64
#  1   mean_texture     569 non-null    float64
#  2   mean_perimeter   569 non-null    float64
#  3   mean_area        569 non-null    float64
#  4   mean_smoothness  569 non-null    float64
#  5   diagnosis        569 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 26.8 KB

# %%
sns.countplot(x=df['diagnosis'])

# %%
plt.figure(figsize=(20,15))
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002484DCE3040>,
# ...
#       dtype=object)

# %%
sns.pairplot(df,hue='diagnosis')
plt.legend()

# %%
sns.FacetGrid(df,hue='diagnosis').map(plt.scatter,'mean_area','mean_perimeter')

# %%
sns.FacetGrid(df,'diagnosis').map(plt.hist,'mean_radius')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=69)

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
rfc=RandomForestClassifier()
svc=SVC()
gbc=GradientBoostingClassifier()

# %%
rfc.fit(x_train,y_train)
svc.fit(x_train,y_train)
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
x_pred1=rfc.predict(x_test)
x_pred2=svc.predict(x_test)
x_pred3=gbc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc1=accuracy_score(x_pred1,y_test)
print(acc1)
acc2=accuracy_score(x_pred2,y_test)
print(acc2)
acc3=accuracy_score(x_pred3,y_test)
print(acc3)
# Out:
# 0.9181286549707602
# 0.9064327485380117
# 0.9122807017543859

# %%
rfc.estimators_
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=1392566858),
#  DecisionTreeClassifier(max_features='auto', random_state=1258172570),
#  DecisionTreeClassifier(max_features='auto', random_state=472885953),
#  DecisionTreeClassifier(max_features='auto', random_state=2001028226),
#  DecisionTreeClassifier(max_features='auto', random_state=1045254622),
#  DecisionTreeClassifier(max_features='auto', random_state=1955412954),
#  DecisionTreeClassifier(max_features='auto', random_state=2060691233),
#  DecisionTreeClassifier(max_features='auto', random_state=1724106667),
#  DecisionTreeClassifier(max_features='auto', random_state=472644072),
#  DecisionTreeClassifier(max_features='auto', random_state=228589573),
#  DecisionTreeClassifier(max_features='auto', random_state=761701213),
#  DecisionTreeClassifier(max_features='auto', random_state=273468882),
#  DecisionTreeClassifier(max_features='auto', random_state=1799510785),
# ...

# %%
print(rfc.max_depth)
# Out:
# None

# %%
from sklearn.metrics import confusion_matrix
cm1=confusion_matrix(x_pred1,y_test)
print(cm1)
cm2=confusion_matrix(x_pred2,y_test)
print(cm2)
cm3=confusion_matrix(x_pred3,y_test)
print(cm3)
# Out:
# [[65  2]
#  [12 92]]
# [[66  5]
#  [11 89]]
# [[66  4]
#  [11 90]]

# %%
import pickle
pickle.dump(rfc,open('model4.pkl','wb'))
